# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  downloading the CSV file.

# %%
from urllib.request import urlretrieve

urlretrieve('https://gist.githubusercontent.com/aakashns/28b2e504b3350afd9bdb157893f9725c/raw/994b65665757f4f8887db1c85986a897abb23d84/countries.csv',
            'countries.csv')
# Out:
# ('countries.csv', <http.client.HTTPMessage at 0x7b599ede15a0>)

# %%
countries_df = pd.read_csv('countries.csv')
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %%
countries_df.shape
# Out:
# (210, 6)

# %% [markdown]
# : How many countries does the dataframe contain?
# 209

# %%
num_countries = countries_df.shape[0] -1

# %%
print('There are {} countries in the dataset'.format(num_countries))
# Out:
# There are 209 countries in the dataset

# %%
list_continent = countries_df['continent'].unique()
list_continent
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
total_population = countries_df['population'].sum()
total_population
# Out:
# 7757980095.0

# %%
weight = countries_df['population'] / total_population
weight
# Out:
# 0      0.005018
# 1      0.000371
# 2      0.005652
# 3      0.000010
# 4      0.004236
#          ...
# 205    0.012547
# 206    0.000077
# 207    0.003845
# 208    0.002370
# 209    0.001916
# Name: population, Length: 210, dtype: float64

# %%
average_life_expectancy = (countries_df['life_expectancy'] * weight).sum()
average_life_expectancy
# Out:
# 72.72165193409664

# %% [markdown]
#  dataframe containing 10 countries with the highest population.

# %%
most_population = countries_df.sort_values('population', ascending=False ).reset_index(drop=True).head(10)
most_population
# Out:
#         location      continent    population  life_expectancy  \
# 0          China           Asia  1.439324e+09            76.91
# 1          India           Asia  1.380004e+09            69.66
# 2  United States  North America  3.310026e+08            78.86
# 3      Indonesia           Asia  2.735236e+08            71.72
# 4       Pakistan           Asia  2.208923e+08            67.27
# 5         Brazil  South America  2.125594e+08            75.88
# 6        Nigeria         Africa  2.061396e+08            54.69
# 7     Bangladesh           Asia  1.646894e+08            72.59
# 8         Russia         Europe  1.459345e+08            72.58
# 9         Mexico  North America  1.289328e+08            75.05
#
#    hospital_beds_per_thousand  gdp_per_capita
# 0                        4.34       15308.712
# 1                        0.53        6426.674
# 2                        2.77       54225.446
# 3                        1.04       11188.744
# ...

# %% [markdown]
# new column in countries_df to record the overall GDP per country

# %%
country_gdp = countries_df['population'] * countries_df['gdp_per_capita']
country_gdp
# Out:
# 0      7.022622e+10
# 1      3.396791e+10
# 2      6.101364e+11
# 3               NaN
# 4      1.912651e+11
#            ...
# 205    6.007624e+11
# 206             NaN
# 207    4.411699e+10
# 208    6.782303e+10
# 209    2.823622e+10
# Length: 210, dtype: float64

# %%
countries_df['gdp'] = country_gdp
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                          0.50        1803.987  7.022622e+10
# 1                          2.89       11803.431  3.396791e+10
# 2                          1.90       13913.839  6.101364e+11
# ...

# %% [markdown]
#  dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.

# %%
#countries with population grater than 100 million
filter_population = countries_df[countries_df['population'] > 100000000]
filter_population
# Out:
#           location      continent    population  life_expectancy  \
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 58           Egypt         Africa  1.023344e+08            71.99
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 90           India           Asia  1.380004e+09            69.66
# 91       Indonesia           Asia  2.735236e+08            71.72
# 99           Japan           Asia  1.264765e+08            84.63
# 125         Mexico  North America  1.289328e+08            75.05
# 141        Nigeria         Africa  2.061396e+08            54.69
# 145       Pakistan           Asia  2.208923e+08            67.27
# 151    Philippines           Asia  1.095811e+08            71.23
# 157         Russia         Europe  1.459345e+08            72.58
# ...

# %%
#sort by gdp per capita
sort_df = filter_population.sort_values('gdp_per_capita')
sort_df
# Out:
#           location      continent    population  life_expectancy  \
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 145       Pakistan           Asia  2.208923e+08            67.27
# 141        Nigeria         Africa  2.061396e+08            54.69
# 90           India           Asia  1.380004e+09            69.66
# 151    Philippines           Asia  1.095811e+08            71.23
# 58           Egypt         Africa  1.023344e+08            71.99
# 91       Indonesia           Asia  2.735236e+08            71.72
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 125         Mexico  North America  1.289328e+08            75.05
# 157         Russia         Europe  1.459345e+08            72.58
# 99           Japan           Asia  1.264765e+08            84.63
# ...

# %%
lowest_gdp = sort_df.head(10)
lowest_gdp
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 63                         0.30        1729.927  1.988786e+11
# 15                         0.80        3523.984  5.803628e+11
# 145                        0.60        5034.708  1.112128e+12
# ...

# %% [markdown]
# count number of countries in contenent

# %%
country_count = countries_df.groupby('continent')['location'].count()
country_count
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %% [markdown]
# total population in each contenent

# %%
total_population_continent = countries_df.groupby('continent')['population'].sum()
total_population_continent
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %% [markdown]
# covid data csv file

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/b2a968a6cfd9fbbb0ff3d6bd0f26262b/raw/b115ed1dfa17f10fc88bf966236cd4d9032f1df8/covid-countries-data.csv',
            'covid-countries-data.csv')
# Out:
# ('covid-countries-data.csv', <http.client.HTTPMessage at 0x7b599842fb80>)

# %%
covid_data_df = pd.read_csv('covid-countries-data.csv')
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# total missing test

# %%
covid_data_df['total_tests'].isna().sum()
# Out:
# 122

# %% [markdown]
# merge two csv file countries_df and covid_data_df on location column

# %%
mearged_df = countries_df.merge(covid_data_df, on='location')
mearged_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# add column tests_per_million, cases_per_million and deaths_per_million into combined_df.

# %%
mearged_df['tests_per_million'] = mearged_df['total_tests'] * 1e6 / mearged_df['population']
mearged_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %%
mearged_df['cases_per_million'] = mearged_df['total_cases'] * 1e6 / mearged_df['population']
mearged_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %%
mearged_df['deaths_per_million'] = mearged_df['total_deaths'] * 1e6 / mearged_df['population']
mearged_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# 10 countries with highest test per million

# %%
highest_test_per_million = mearged_df.sort_values('tests_per_million', ascending=False).head(10)
highest_test_per_million
# Out:
#                  location      continent   population  life_expectancy  \
# 197  United Arab Emirates           Asia    9890400.0            77.97
# 14                Bahrain           Asia    1701583.0            77.29
# 115            Luxembourg         Europe     625976.0            82.25
# 122                 Malta         Europe     441539.0            82.53
# 53                Denmark         Europe    5792203.0            80.90
# 96                 Israel           Asia    8655541.0            82.97
# 89                Iceland         Europe     341250.0            82.99
# 157                Russia         Europe  145934460.0            72.58
# 199         United States  North America  331002647.0            78.86
# 10              Australia        Oceania   25499881.0            83.44
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 197                       1.200       67293.483  6.655595e+11      71540.0
# ...

# %% [markdown]
# 10 countries with  highest number of positive cases per million people.

# %%
highest_positive_cases_per_million = mearged_df.sort_values('cases_per_million', ascending=False).head(10)
highest_positive_cases_per_million
# Out:
#           location      continent   population  life_expectancy  \
# 155          Qatar           Asia    2881060.0            80.23
# 14         Bahrain           Asia    1701583.0            77.29
# 147         Panama  North America    4314768.0            78.51
# 40           Chile  South America   19116209.0            80.18
# 162     San Marino         Europe      33938.0            84.97
# 9            Aruba  North America     106766.0            76.29
# 105         Kuwait           Asia    4270563.0            75.49
# 150           Peru  South America   32971846.0            76.74
# 27          Brazil  South America  212559409.0            75.88
# 199  United States  North America  331002647.0            78.86
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 155                        1.20      116935.600  3.368985e+11     119206.0
# 14                         2.00       43290.705  7.366273e+10      52440.0
# ...

# %% [markdown]
# 10 countires that have highest number of deaths cases per million people

# %%
highest_death_cases_per_million = mearged_df.sort_values('deaths_per_million', ascending=False).head(10)
highest_death_cases_per_million
# Out:
#            location      continent   population  life_expectancy  \
# 162      San Marino         Europe      33938.0            84.97
# 150            Peru  South America   32971846.0            76.74
# 18          Belgium         Europe   11589616.0            81.63
# 3           Andorra         Europe      77265.0            83.73
# 177           Spain         Europe   46754783.0            83.56
# 198  United Kingdom         Europe   67886004.0            81.32
# 40            Chile  South America   19116209.0            80.18
# 97            Italy         Europe   60461828.0            83.51
# 27           Brazil  South America  212559409.0            75.88
# 182          Sweden         Europe   10099270.0            82.80
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 162                        3.80       56861.470  1.929765e+09        735.0
# 150                        1.60       12236.706  4.034668e+11     663437.0
# ...

# %% [markdown]
# number of countries that feature in both the lists of "highest number of tests per million" and "highest number of cases per million"

# %%
both_df = pd.merge(highest_test_per_million, highest_positive_cases_per_million, on='location')
both_df
# Out:
#         location    continent_x  population_x  life_expectancy_x  \
# 0        Bahrain           Asia     1701583.0              77.29
# 1  United States  North America   331002647.0              78.86
#
#    hospital_beds_per_thousand_x  gdp_per_capita_x         gdp_x  \
# 0                          2.00         43290.705  7.366273e+10
# 1                          2.77         54225.446  1.794877e+13
#
#    total_cases_x  total_deaths_x  total_tests_x  ...  life_expectancy_y  \
# 0        52440.0           190.0      1118837.0  ...              77.29
# 1      6114406.0        185744.0     83898416.0  ...              78.86
#
#    hospital_beds_per_thousand_y  gdp_per_capita_y         gdp_y  \
# 0                          2.00         43290.705  7.366273e+10
# 1                          2.77         54225.446  1.794877e+13
#
#    total_cases_y  total_deaths_y  total_tests_y  tests_per_million_y  \
# 0        52440.0           190.0      1118837.0        657527.137965
# ...

# %%
len(both_df)
print (f'{len(both_df)} countries feature in both the lists of highest number of tests per million and highest number of cases per million')
# Out:
# 2 countries feature in both the lists of highest number of tests per million and highest number of cases per million

# %% [markdown]
# number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.

# %%
#country filter with population more than 10 million
filter_country = mearged_df[mearged_df['population'] > 10000000]
filter_country
# Out:
#         location      continent  population  life_expectancy  \
# 0    Afghanistan           Asia  38928341.0            64.83
# 2        Algeria         Africa  43851043.0            76.88
# 4         Angola         Africa  32866268.0            61.15
# 7      Argentina  South America  45195777.0            76.67
# 10     Australia        Oceania  25499881.0            83.44
# ..           ...            ...         ...              ...
# 204    Venezuela  South America  28435943.0            72.06
# 205      Vietnam           Asia  97338583.0            75.40
# 207        Yemen           Asia  29825968.0            66.12
# 208       Zambia         Africa  18383956.0            63.89
# 209     Zimbabwe         Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 2                          1.90       13913.839  6.101364e+11      45158.0
# ...

# %%
#20 countries with lowesr gdp

lowest_gdp = filter_country.sort_values('gdp_per_capita').nsmallest(20, 'gdp_per_capita')
lowest_gdp
# Out:
#                          location      continent   population  \
# 32                        Burundi         Africa   11890781.0
# 52   Democratic Republic of Congo         Africa   89561404.0
# 140                         Niger         Africa   24206636.0
# 118                        Malawi         Africa   19129955.0
# 132                    Mozambique         Africa   31255435.0
# 117                    Madagascar         Africa   27691019.0
# 207                         Yemen           Asia   29825968.0
# 176                   South Sudan         Africa   11193729.0
# 85                          Haiti  North America   11402533.0
# 195                        Uganda         Africa   45741000.0
# 31                   Burkina Faso         Africa   20903278.0
# 63                       Ethiopia         Africa  114963583.0
# 39                           Chad         Africa   16425859.0
# 0                     Afghanistan           Asia   38928341.0
# ...

# %%
#20 countries with lowest bed count
lowest_hospital_beds = filter_country.sort_values('hospital_beds_per_thousand').nsmallest(20, 'hospital_beds_per_thousand')
lowest_hospital_beds
# Out:
#          location      continent    population  life_expectancy  \
# 121          Mali         Africa  2.025083e+07            59.31
# 117    Madagascar         Africa  2.769102e+07            67.04
# 140         Niger         Africa  2.420664e+07            62.42
# 135         Nepal           Asia  2.913681e+07            70.78
# 82         Guinea         Africa  1.313279e+07            61.60
# 63       Ethiopia         Africa  1.149636e+08            66.60
# 31   Burkina Faso         Africa  2.090328e+07            61.58
# 195        Uganda         Africa  4.574100e+07            63.37
# 0     Afghanistan           Asia  3.892834e+07            64.83
# 20          Benin         Africa  1.212320e+07            61.77
# 90          India           Asia  1.380004e+09            69.66
# 80      Guatemala  North America  1.791557e+07            74.30
# 145      Pakistan           Asia  2.208923e+08            67.27
# 85          Haiti  North America  1.140253e+07            64.00
# ...

# %%
common = pd.merge(lowest_gdp, lowest_hospital_beds, on='location')
common
# Out:
#         location    continent_x  population_x  life_expectancy_x  \
# 0        Burundi         Africa    11890781.0              61.58
# 1          Niger         Africa    24206636.0              62.42
# 2     Mozambique         Africa    31255435.0              60.85
# 3     Madagascar         Africa    27691019.0              67.04
# 4          Yemen           Asia    29825968.0              66.12
# 5          Haiti  North America    11402533.0              64.00
# 6         Uganda         Africa    45741000.0              63.37
# 7   Burkina Faso         Africa    20903278.0              61.58
# 8       Ethiopia         Africa   114963583.0              66.60
# 9    Afghanistan           Asia    38928341.0              64.83
# 10        Guinea         Africa    13132792.0              61.60
# 11          Mali         Africa    20250834.0              59.31
# 12         Benin         Africa    12123198.0              61.77
# ...

# %%
number = len(common)
print(f'{number} countries feature in both the lists')
# Out:
# 14 countries feature in both the lists
